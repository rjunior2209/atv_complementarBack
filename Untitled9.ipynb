# %% [markdown]
# <a href="https://colab.research.google.com/github/rjunior2209/atv_complementarBack/blob/master/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
train_df = pd.read_csv("train.csv")

# %%
train_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
train_df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 868          869         0       3             van Melkebeke, Mr. Philemon
# 643          644         1       3                         Foo, Mr. Choong
# 65            66         1       3                Moubarek, Master. Gerios
# 199          200         0       2  Yrois, Miss. Henriette ("Mrs Harbeck")
# 762          763         1       3                   Barah, Mr. Hanna Assi
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 868    male   NaN      0      0  345777   9.5000   NaN        S
# 643    male   NaN      0      0    1601  56.4958   NaN        S
# 65     male   NaN      1      1    2661  15.2458   NaN        C
# 199  female  24.0      0      0  248747  13.0000   NaN        S
# 762    male  20.0      0      0    2663   7.2292   NaN        C
